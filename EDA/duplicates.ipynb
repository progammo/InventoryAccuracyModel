# %%
import pandas as pd

# %%
df = pd.read_csv("D:\\Priceoye\\Inventory_Accuracy_ModelV1\\Data\\sales_inventory.csv")

# %%
df.value_counts()
# Out:
# date       sku_id            brand    units_sold  restocked_units  recorded_stock  price
# 3/31/2026  SKU_SAMSUNG_0173  Samsung  5.0         0                0               213287    3
# 3/4/2026   SKU_SAMSUNG_0176  Samsung  9.0         0                0               303978    3
# 3/5/2026   SKU_SAMSUNG_0180  Samsung  7.0         0                0               105456    3
# 6/24/2026  SKU_APPLE_0190    Apple    1.0         0                0               402460    3
# 6/23/2026  SKU_APPLE_0192    Apple    5.0         0                0               202368    3
#                                                                                             ..
# 6/25/2026  SKU_GOOGLE_0200   Google   2.0         0                0               279911    1
# 6/26/2026  SKU_GOOGLE_0200   Google   4.0         36               32              279911    1
# 6/27/2026  SKU_GOOGLE_0200   Google   3.0         0                29              279911    1
# 6/28/2026  SKU_GOOGLE_0200   Google   8.0         0                21              279911    1
# 6/29/2026  SKU_GOOGLE_0200   Google   4.0         0                17              279911    1
# Name: count, Length: 107137, dtype: int64

# %%
duplicates = df[df.duplicated(subset=['date', 'sku_id', 'brand'], keep=False)]

# %%
duplicates.value_counts()
# Out:
# date       sku_id            brand    units_sold  restocked_units  recorded_stock  price
# 3/31/2026  SKU_SAMSUNG_0173  Samsung  5.0         0                0               213287    3
# 3/4/2026   SKU_SAMSUNG_0176  Samsung  9.0         0                0               303978    3
# 3/5/2026   SKU_SAMSUNG_0180  Samsung  7.0         0                0               105456    3
# 6/24/2026  SKU_APPLE_0190    Apple    1.0         0                0               402460    3
# 6/23/2026  SKU_APPLE_0192    Apple    5.0         0                0               202368    3
#                                                                                             ..
# 6/25/2026  SKU_GOOGLE_0200   Google   2.0         0                0               279911    1
# 6/26/2026  SKU_GOOGLE_0200   Google   4.0         36               32              279911    1
# 6/27/2026  SKU_GOOGLE_0200   Google   3.0         0                29              279911    1
# 6/28/2026  SKU_GOOGLE_0200   Google   8.0         0                21              279911    1
# 6/29/2026  SKU_GOOGLE_0200   Google   4.0         0                17              279911    1
# Name: count, Length: 107137, dtype: int64

# %%
duplicates_df = duplicates.sort_values(by=['sku_id', 'date'])
duplicates_df
# Out:
#              date           sku_id         brand  units_sold  restocked_units  \
# 101520   1/1/2026   SKU_APPLE_0189         Apple         0.0                9
# 101700   1/1/2026   SKU_APPLE_0189         Apple         3.0                0
# 101880   1/1/2026   SKU_APPLE_0189         Apple         1.0                0
# 101529  1/10/2026   SKU_APPLE_0189         Apple         4.0                0
# 101709  1/10/2026   SKU_APPLE_0189         Apple         6.0                0
# ...           ...              ...           ...         ...              ...
# 89438    6/8/2026  SKU_XIAOMI_0166  Xiaomi/Redmi        16.0                0
# 89618    6/8/2026  SKU_XIAOMI_0166  Xiaomi/Redmi        14.0                0
# 89259    6/9/2026  SKU_XIAOMI_0166  Xiaomi/Redmi         8.0                0
# 89439    6/9/2026  SKU_XIAOMI_0166  Xiaomi/Redmi        14.0                0
# 89619    6/9/2026  SKU_XIAOMI_0166  Xiaomi/Redmi         7.0                0
#
#         recorded_stock   price
# 101520              49  233583
# 101700              50  233583
# 101880              46  233583
# 101529              27  233583
# 101709               0  233583
# ...                ...     ...
# 89438                0   59766
# 89618                0   59766
# 89259               37   59766
# 89439                0   59766
# 89619                0   59766
#
# [108000 rows x 7 columns]

# %%
duplicates_df = df[df.duplicated(subset=['date', 'sku_id'], keep=False)]

# Sort them so duplicate pairs/groups sit next to each other for easy viewing
duplicates_df = duplicates_df.sort_values(by=['sku_id', 'date'])

print(f"Total duplicate rows found: {len(duplicates_df)}")
print(duplicates_df.head(20))
# Out:
# Total duplicate rows found: 108000
#              date          sku_id  brand  units_sold  restocked_units  \
# 101520   1/1/2026  SKU_APPLE_0189  Apple         0.0                9
# 101700   1/1/2026  SKU_APPLE_0189  Apple         3.0                0
# 101880   1/1/2026  SKU_APPLE_0189  Apple         1.0                0
# 101529  1/10/2026  SKU_APPLE_0189  Apple         4.0                0
# 101709  1/10/2026  SKU_APPLE_0189  Apple         6.0                0
# 101889  1/10/2026  SKU_APPLE_0189  Apple         7.0                0
# 101530  1/11/2026  SKU_APPLE_0189  Apple         3.0                0
# 101710  1/11/2026  SKU_APPLE_0189  Apple         3.0                0
# 101890  1/11/2026  SKU_APPLE_0189  Apple         9.0                0
# 101531  1/12/2026  SKU_APPLE_0189  Apple         1.0                0
# 101711  1/12/2026  SKU_APPLE_0189  Apple         2.0               41
# 101891  1/12/2026  SKU_APPLE_0189  Apple         0.0                0
# 101532  1/13/2026  SKU_APPLE_0189  Apple         4.0                0
# 101712  1/13/2026  SKU_APPLE_0189  Apple         2.0                0
# 101892  1/13/2026  SKU_APPLE_0189  Apple         3.0                0
# 101533  1/14/2026  SKU_APPLE_0189  Apple         8.0                0
# 101713  1/14/2026  SKU_APPLE_0189  Apple         4.0                0
# 101893  1/14/2026  SKU_APPLE_0189  Apple         6.0                0
# 101534  1/15/2026  SKU_APPLE_0189  Apple         2.0               42
# 101714  1/15/2026  SKU_APPLE_0189  Apple         1.0                0
#
#         recorded_stock   price
# 101520              49  233583
# 101700              50  233583
# 101880              46  233583
# 101529              27  233583
# 101709               0  233583
# 101889              71  233583
# 101530              24  233583
# 101710               0  233583
# 101890              62  233583
# 101531              23  233583
# 101711              39  233583
# 101891              62  233583
# 101532              19  233583
# 101712              37  233583
# 101892              59  233583
# 101533              11  233583
# 101713              33  233583
# 101893              53  233583
# 101534              51  233583
# 101714              32  233583

# %%
# Drop duplicates, keeping the first occurrence of each record
df_clean = df.drop_duplicates()

# If using specific columns to define uniqueness:
# df_clean = df.drop_duplicates(subset=['date', 'sku_id'], keep='first')

print(f"Original row count: {len(df)}")
print(f"Cleaned row count:  {len(df_clean)}")
print(f"Total rows dropped: {len(df) - len(df_clean)}")
# Out:
# Original row count: 108000
# Cleaned row count:  107137
# Total rows dropped: 863
